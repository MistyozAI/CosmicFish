# %%
try:
    from flash_attn.bert_padding import index_first_axis
    from flash_attn.flashattn_interface import flash_attn_unpadded
    print("✅ FlashAttention is installed and importable.")
except ImportError as e:
    print("❌ FlashAttention not available:", e)

# %%
import torch

print("CUDA available:", torch.cuda.is_available())
print("Device:", torch.cuda.get_device_name(0))
print("Supports bf16:", torch.cuda.is_bf16_supported())
print("Supports fp16:", torch.cuda.get_device_capability(0)[0] >= 7)

cap = torch.cuda.get_device_capability(0)
print(f"Compute Capability: {cap} (sm_{cap[0]}{cap[1]})")

# %%
import torch

print(f"Max memory allocated: {torch.cuda.max_memory_allocated() / 1e9:.2f} GB")
print(f"Max memory reserved : {torch.cuda.max_memory_reserved() / 1e9:.2f} GB")
print(f"Current memory allocated: {torch.cuda.memory_allocated() / 1e9:.2f} GB")
print(f"Current memory reserved : {torch.cuda.memory_reserved() / 1e9:.2f} GB")

# %%
# !nvidia-smi

# %%
# %run test.py --model_path=out/pretrained/ckpt.pt --interactive --temperature=0.4 --max_tokens=200

# %%
cp /workspace/out/pretrained/ckpt.pt /workspace/best_yet_16.54perp.pt

# %%
cp /workspace/out/pretrained/ckpt.pt /workspace/Base_300M.pt

# %%
# %run chat.py --model_path=out/calibrated/calibrated_002000.pt

# %%
# %run chat.py --model_path=out/calibrated/best_calibrated.pt
