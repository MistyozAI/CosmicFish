# %%
# !pip install torch tiktoken tqdm numpy transformers requests colorama customtkinter psutil termcolor gdown matplotlib wandb

# %%
# !pip install datasets gdown

# %%
#CF 300M
# !gdown 1fHstX35i7v2uSg8XIqBrq7Y8Te7WopOi

# %%
#CF 120M
# !gdown 13jQ2iYWYJYn8FPf8i5AuK5ZYgfRlrphF

# %%
#CF 90M
# !gdown 1b18qTkDfC_tmtyEwnTOa-W1xN3qZhLEC

# %%
#CF 30M
# !gdown 17_GtwXHTDxBbjE2uvZyWmuTBFE5WIzBD

# %%
# !python eval1.py --checkpoint CF30M.pt

# %%
# !python eval1oth.py --mode all

# %%
# !python eval2.py --checkpoint CF30M.pt

# %%
# !python eval2oth.py --model all
# Out:
# 11:59:57  INFO  Device: cuda
# 11:59:57  INFO
# Pre-loading datasets …
# 11:59:57  INFO  Loading TriviaQA …
# 11:59:58  INFO    TriviaQA: 7993 examples
# 11:59:58  INFO  Loading Natural Questions …
# 11:59:58  INFO    Natural Questions: 3610 examples
# 11:59:58  INFO  Loading ARC-Easy …
# 11:59:58  INFO    ARC-Easy: 570 examples
# 11:59:58  INFO
# ...
# 11:59:58  INFO  Model: GPT2
# 11:59:58  INFO  ============================================================
# 11:59:59  INFO  Loading gpt2 (gpt2) …
# 12:00:00  INFO  HTTP Request: HEAD https://huggingface.co/gpt2/resolve/main/config.json "HTTP/1.1 200 OK"
# ...
# 12:00:00  WARNING  Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 12:00:00  INFO  HTTP Request: HEAD https://huggingface.co/gpt2/resolve/main/tokenizer_config.json "HTTP/1.1 200 OK"
# ...
